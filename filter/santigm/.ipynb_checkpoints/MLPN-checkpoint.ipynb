# %%
import pandas as pd
from sklearn.neural_network import MLPClassifier as MLPNC
from sklearn.externals import joblib as joblib
from sklearn.preprocessing import MinMaxScaler

# %%
trn_df = pd.read_csv('filter/datosEntrenamiento.csv', header=None)
tst_df = pd.read_csv('filter/datosPrueba.csv', header=None)
tst_idx = trn_df.shape[0] # guardar donde empiezan los datos de prueba
full_df = pd.concat([trn_df, tst_df]) #juntar datos de entrenamiento y prueba
full_df = (full_df - full_df.min())/(full_df.max() - full_df.min()) # escalar en [0,1](MLPN)
full_df.head(10)
# Out:
#          0         1         2         3         4         5         6   \
# 0  0.815385  0.800000  0.770115  0.504132  0.692308  0.681818  0.589474
# 1  0.692308  0.681818  0.563218  0.413223  0.630769  0.681818  0.547368
# 2  0.692308  0.609091  0.563218  0.380165  0.630769  0.609091  0.505263
# 3  0.630769  0.609091  0.517241  0.355372  0.630769  0.681818  0.547368
# 4  0.569231  0.681818  0.609195  0.413223  0.569231  0.681818  0.589474
# 5  0.569231  0.681818  0.609195  0.446281  0.630769  0.645455  0.589474
# 6  0.569231  0.563636  0.517241  0.355372  0.569231  0.609091  0.505263
# 7  0.569231  0.645455  0.563218  0.322314  0.569231  0.609091  0.421053
# 8  0.507692  0.609091  0.425287  0.322314  0.507692  0.563636  0.463158
# 9  0.507692  0.563636  0.471264  0.355372  0.507692  0.563636  0.505263
#
#          7         8         9  ...      27        28        29        30  \
# 0  0.390625  0.709677  0.728155 ...   0.600  0.753846  0.912621  0.815217
# ...

# %%
def eval_model(y_hat, y):
    n_elem_sel = y_hat[y_hat==1].size
    true_pos = y[(y==1)&(y==y_hat)].size
    false_neg = y[(y==0)&(y!=y_hat)].size
    false_pos = y[(y==1)&(y!=y_hat)].size
    true_neg = y[(y==0)&(y==y_hat)].size
    
    precision = true_pos/n_elem_sel
    tasa_v_pos = true_pos/(true_pos+false_neg)
    tasa_f_pos = false_pos/(true_neg+false_pos)
    return precision, tasa_v_pos, tasa_f_pos

# %%
# volver a dividir el dataset
trn_X = full_df.iloc[:tst_idx,:-1]
trn_Y = full_df.iloc[:tst_idx,full_df.shape[1]-1]
tst_X = full_df.iloc[tst_idx:,:-1]
tst_Y = full_df.iloc[tst_idx:,full_df.shape[1]-1]

le = preprocessing.LabelEncoder()
le.fit(trn_Y)
trn_Y = le.transform(trn_Y) # needed for MLPNClassifier
tst_Y = le.transform(tst_Y)

mlpn = MLPNC(solver='lbfgs', alpha=1e-5, hidden_layer_sizes=(100,))
mlpn.fit(trn_X, trn_Y)
print("score= %f"%(mlpn.score(tst_X, tst_Y)))
# Out:
# score= 0.892774

# %%
joblib.dump(mlpn, 'models/MLPC.pkl')
# Out:
# ['models/MLPC.pkl']
